# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install citipy
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import matplotlib.cm as cm
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create url
url = 'http://api.openweathermap.org/data/2.5/weather?'

# Define units
units = 'imperial'

# Create query url with weather_api_key and units
query = f"{url}appid={weather_api_key}&units={units}&q="

# Json response
response = requests.get(query + city).json()
response
# Out:
# {'coord': {'lon': -155.09, 'lat': 19.7297},
#  'weather': [{'id': 502,
#    'main': 'Rain',
#    'description': 'heavy intensity rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 72.16,
#   'feels_like': 68.2,
#   'temp_min': 66,
#   'temp_max': 77,
#   'pressure': 1014,
#   'humidity': 69},
#  'visibility': 10000,
#  'wind': {'speed': 13.8, 'deg': 90},
#  'rain': {'1h': 5.08},
#  'clouds': {'all': 75},
#  'dt': 1616546505,
#  'sys': {'type': 1,
#   'id': 7881,
#   'country': 'US',
#   'sunrise': 1616516481,
#   'sunset': 1616560324},
#  'timezone': -36000,
#  'id': 5855927,
#  'name': 'Hilo',
#  'cod': 200}

# %%
# print log for process section
city_name = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
record = 0
set_one = 1

# start request
print(f'data request start')
print(f'---')

# looping for lists
for city in cities:
    try:
        response = requests.get(query + city).json()
        city_name.append(response['name'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temperature.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_record = response ['name']
        if record > 49:
            record = 1
            set_one += 1
        else:
            record += 1
        
#       for city found
        print(f'Processing Record {record} of Set {set_one} | {city_record}')
        
#       city not found
    except: 
        print(f'City not found.  Skipping...')

# Print Data Retrieval Complete
print("---")
print("Data Complete")
# Out:
# data request start
# ---
# Processing Record 1 of Set 1 | Kysyl-Syr
# Processing Record 2 of Set 1 | Kamaishi
# Processing Record 3 of Set 1 | Saskylakh
# Processing Record 4 of Set 1 | Cape Town
# City not found.  Skipping...
# Processing Record 5 of Set 1 | Barrow
# Processing Record 6 of Set 1 | Río Gallegos
# Processing Record 7 of Set 1 | Rikitea
# Processing Record 8 of Set 1 | Vila Franca do Campo
# Processing Record 9 of Set 1 | Cidreira
# Processing Record 10 of Set 1 | Mogadishu
# Processing Record 11 of Set 1 | Albany
# Processing Record 12 of Set 1 | Yulara
# Processing Record 13 of Set 1 | Tessalit
# Processing Record 14 of Set 1 | Yellowknife
# City not found.  Skipping...
# Processing Record 15 of Set 1 | Lavrentiya
# Processing Record 16 of Set 1 | Ponta do Sol
# Processing Record 17 of Set 1 | Hithadhoo
# Processing Record 18 of Set 1 | Vaini
# Processing Record 19 of Set 1 | Bawku
# Processing Record 20 of Set 1 | Boguchany
# Processing Record 21 of Set 1 | Yeppoon
# Processing Record 22 of Set 1 | Bilibino
# Processing Record 11 of Set 5 | Sola
# City not found.  Skipping...
# Processing Record 12 of Set 5 | Honningsvåg
# Processing Record 13 of Set 5 | Grande Prairie
# Processing Record 14 of Set 5 | Prince Albert
# Processing Record 15 of Set 5 | Zhicheng
# Processing Record 16 of Set 5 | Quatre Cocos
# Processing Record 17 of Set 5 | Port Macquarie
# Processing Record 18 of Set 5 | Alta Floresta
# Processing Record 19 of Set 5 | Hadano
# Processing Record 20 of Set 5 | Kichera
# Processing Record 21 of Set 5 | Rockford
# Processing Record 22 of Set 5 | Fortuna
# Processing Record 23 of Set 5 | Constitución
# Processing Record 24 of Set 5 | Sioux Lookout
# Processing Record 25 of Set 5 | Oparino
# Processing Record 26 of Set 5 | Caravelas
# Processing Record 27 of Set 5 | Masterton
# Processing Record 28 of Set 5 | Kirakira
# Processing Record 29 of Set 5 | Castelo do Piauí
# Processing Record 30 of Set 5 | Los Llanos de Aridane
# Processing Record 31 of Set 5 | Praia
# Processing Record 32 of Set 5 | Shwebo
# Processing Record 33 of Set 5 | Rantepao
# Processing Record 34 of Set 5 | Carutapera
# Processing Record 35 of Set 5 | Elizabeth City
# Processing Record 36 of Set 5 | Iqaluit
# Processing Record 37 of Set 5 | Kologriv
# Processing Record 38 of Set 5 | Seddon
# Processing Record 39 of Set 5 | Torbay
# Processing Record 40 of Set 5 | Bambous Virieux
# Processing Record 41 of Set 5 | Tangwani
# Processing Record 42 of Set 5 | Olinda
# Processing Record 43 of Set 5 | Wānkāner
# Processing Record 44 of Set 5 | Ostrovnoy
# Processing Record 45 of Set 5 | Flinders
# Processing Record 46 of Set 5 | Leningradskiy
# Processing Record 47 of Set 5 | Dunmanway
# Processing Record 48 of Set 5 | Calama
# Processing Record 49 of Set 5 | Camacha
# Processing Record 50 of Set 5 | Acaraú
# Processing Record 1 of Set 6 | Satipo
# Processing Record 2 of Set 6 | Blenheim
# Processing Record 3 of Set 6 | Sweetwater
# Processing Record 4 of Set 6 | Djebeniana
# Processing Record 5 of Set 6 | Zhoucheng
# Processing Record 6 of Set 6 | Manzanares
# Processing Record 7 of Set 6 | Kawalu
# Processing Record 8 of Set 6 | Eydhafushi
# Processing Record 9 of Set 6 | Marabu
# Processing Record 10 of Set 6 | Río Cuarto
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 11 of Set 6 | Tynda
# Processing Record 12 of Set 6 | Coruripe
# City not found.  Skipping...
# Processing Record 13 of Set 6 | Fare
# Processing Record 14 of Set 6 | Pecos
# Processing Record 15 of Set 6 | Vanimo
# Processing Record 16 of Set 6 | Chokurdakh
# Processing Record 17 of Set 6 | Hong Kong
# Processing Record 18 of Set 6 | Sept-Îles
# Processing Record 19 of Set 6 | Kruisfontein
# Processing Record 20 of Set 6 | College
# Processing Record 21 of Set 6 | Paita
# Processing Record 22 of Set 6 | Provincie Utrecht
# Processing Record 23 of Set 6 | Anaco
# Processing Record 24 of Set 6 | Puttūr
# Processing Record 18 of Set 10 | Alberton
# Processing Record 19 of Set 10 | Haines Junction
# Processing Record 20 of Set 10 | Dhārchula
# Processing Record 21 of Set 10 | Pengcheng
# Processing Record 22 of Set 10 | Constantine
# Processing Record 23 of Set 10 | Strezhevoy
# Processing Record 24 of Set 10 | Chipinge
# Processing Record 25 of Set 10 | Hirado
# Processing Record 26 of Set 10 | Vila do Maio
# Processing Record 27 of Set 10 | Sechura
# Processing Record 28 of Set 10 | Itupiranga
# Processing Record 29 of Set 10 | Vila Velha
# Processing Record 30 of Set 10 | Mackay
# City not found.  Skipping...
# Processing Record 31 of Set 10 | Lewiston
# City not found.  Skipping...
# Processing Record 32 of Set 10 | Saint-François
# Processing Record 33 of Set 10 | Praia da Vitória
# Processing Record 34 of Set 10 | North Platte
# City not found.  Skipping...
# Processing Record 35 of Set 10 | Bosaso
# Processing Record 36 of Set 10 | Monte Azul
# Processing Record 37 of Set 10 | Mahenge
# Processing Record 38 of Set 10 | Necochea
# Processing Record 39 of Set 10 | Delta del Tigre
# Processing Record 40 of Set 10 | Kano
# Processing Record 41 of Set 10 | Parangan
# Processing Record 42 of Set 10 | Savannakhet
# Processing Record 43 of Set 10 | Ko Samui
# Processing Record 44 of Set 10 | Saint-Pierre
# Processing Record 45 of Set 10 | Vardø
# Processing Record 46 of Set 10 | Tarpa
# City not found.  Skipping...
# Processing Record 47 of Set 10 | Marzuq
# Processing Record 48 of Set 10 | Helena
# City not found.  Skipping...
# Processing Record 49 of Set 10 | Sursee
# Processing Record 50 of Set 10 | Guiratinga
# Processing Record 1 of Set 11 | Atbasar
# Processing Record 2 of Set 11 | Khovd
# Processing Record 3 of Set 11 | Plattsburgh
# Processing Record 4 of Set 11 | Baoqing
# Processing Record 5 of Set 11 | Buraidah
# Processing Record 6 of Set 11 | Cochrane
# Processing Record 7 of Set 11 | Kharp
# Processing Record 8 of Set 11 | Kismayo
# Processing Record 9 of Set 11 | Kirensk
# Processing Record 10 of Set 11 | Berlevåg
# Processing Record 11 of Set 11 | Zhigansk
# Processing Record 12 of Set 11 | Brae
# Processing Record 13 of Set 11 | Cueto
# City not found.  Skipping...
# Processing Record 14 of Set 11 | Waingapu
# Processing Record 15 of Set 11 | Mansehra
# City not found.  Skipping...
# Processing Record 16 of Set 11 | Xingyi
# Processing Record 17 of Set 11 | Makakilo City
# Processing Record 18 of Set 11 | Aurād
# Processing Record 19 of Set 11 | Roald
# Processing Record 20 of Set 11 | Aswān
# Processing Record 21 of Set 11 | Dandeli
# Processing Record 22 of Set 11 | Belaya Gora
# Processing Record 23 of Set 11 | Eyl
# Processing Record 24 of Set 11 | Porto Walter
# Processing Record 25 of Set 11 | Bulancak
# Processing Record 26 of Set 11 | Dūngarpur
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 27 of Set 11 | Lobva
# Processing Record 28 of Set 11 | Port Elizabeth
# Processing Record 29 of Set 11 | Bonthe
# City not found.  Skipping...
# Processing Record 30 of Set 11 | Grand Baie
# Processing Record 31 of Set 11 | Sørland
# Processing Record 32 of Set 11 | Chapais
# Processing Record 33 of Set 11 | Sovetskiy
# Processing Record 34 of Set 11 | Pangkalanbuun
# Processing Record 35 of Set 11 | Dukat
# Processing Record 36 of Set 11 | Iquique
# Processing Record 37 of Set 11 | Abu Kamal
# Processing Record 38 of Set 11 | Kloulklubed
# Processing Record 39 of Set 11 | Oddur
# Processing Record 40 of Set 11 | Vanderhoof
# Processing Record 41 of Set 11 | Mehamn
# City not found.  Skipping...
# Processing Record 42 of Set 11 | Ucluelet
# Processing Record 43 of Set 11 | Mareeba
# City not found.  Skipping...
# Processing Record 44 of Set 11 | Dhidhdhoo
# Processing Record 45 of Set 11 | Touros
# Processing Record 46 of Set 11 | Machilipatnam
# Processing Record 47 of Set 11 | Ketchikan
# Processing Record 48 of Set 11 | Pimenta Bueno
# Processing Record 49 of Set 11 | Puerto Colombia
# Processing Record 50 of Set 11 | Daru
# Processing Record 1 of Set 12 | Tianpeng
# Processing Record 2 of Set 12 | Husavik
# Processing Record 3 of Set 12 | St. George's
# Processing Record 4 of Set 12 | Gijang
# Processing Record 5 of Set 12 | Qaqortoq
# Processing Record 6 of Set 12 | Amreli
# Processing Record 7 of Set 12 | Tiarei
# Processing Record 8 of Set 12 | Koslan
# Processing Record 9 of Set 12 | Batemans Bay
# Processing Record 10 of Set 12 | Miyako
# City not found.  Skipping...
# Processing Record 11 of Set 12 | Vershino-Shakhtaminskiy
# Processing Record 12 of Set 12 | Marawi
# Processing Record 13 of Set 12 | Oodweyne
# Processing Record 14 of Set 12 | Tiksi
# Processing Record 15 of Set 12 | Krasnystaw
# Processing Record 16 of Set 12 | Harar
# Processing Record 17 of Set 12 | Santa Maria
# Processing Record 18 of Set 12 | Longview
# Processing Record 19 of Set 12 | Soyo
# Processing Record 20 of Set 12 | Faya
# Processing Record 21 of Set 12 | Hay River
# Processing Record 22 of Set 12 | Walvis Bay
# Processing Record 23 of Set 12 | Tamworth
# ---
# Data Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# dict data frame for lists
city_data = pd.DataFrame({
    'City': city_name,
    'Country': country,
    'Latitude': latitude,
    'Longitude': longitude,
    'Max Temperature (F)': max_temperature,
    'Humidity (%)': humidity,
    'Cloudiness (%)': cloudiness,
    'Wind Speed (mph)': wind_speed,
    'Date': date
})

# Print and Export
city_data.to_csv(r'../output_data/cities.csv', encoding="utf-8", index=False)
city_data
# Out:
#            City Country  Latitude  Longitude  Max Temperature (F)  \
# 0     Kysyl-Syr      RU   63.8986   122.7617               -11.09
# 1      Kamaishi      JP   39.2667   141.8833                44.60
# 2     Saskylakh      RU   71.9167   114.0833               -27.65
# 3     Cape Town      ZA  -33.9258    18.4232                72.00
# 4        Barrow      US   71.2906  -156.7887                -7.60
# ..          ...     ...       ...        ...                  ...
# 568        Soyo      AO   -6.1349    12.3689                79.68
# 569        Faya      SA   18.3851    42.4509                59.00
# 570   Hay River      CA   60.8156  -115.7999                 5.00
# 571  Walvis Bay      NA  -22.9575    14.5053                64.40
# 572    Tamworth      GB   52.6340    -1.6959                45.00
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 0              95              74              4.36  1616546509
# 1              61              40              5.75  1616546509
# 2              97              88              5.97  1616546280
# 3              68               0              8.05  1616546226
# 4              71               1             11.50  1616546395
# ..            ...             ...               ...         ...
# 568            86             100             10.85  1616546671
# 569            33               0              3.98  1616546672
# 570            72              97              8.05  1616546672
# 571            82              18              3.44  1616546672
# 572            88              96              5.99  1616546469
#
# [573 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  humidity over 100
onehun_humidity = city_data.loc[(city_data['Humidity (%)'] > 100) & (city_data['Humidity (%)'] <= 1000)]
onehun_humidity_df = pd.DataFrame(onehun_humidity)
len(onehun_humidity_df)
# Out:
# 0

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Set x and y values
x_values = city_data['Latitude']
y_values = city_data['Max Temperature (F)']

# Create scatter plot.  Set edgecolor
plt.scatter(x_values,y_values, edgecolor = 'black')

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Max Temperature (01/24/2021)')

# Grid and display scatter plot
plt.grid(zorder=0)
plt.show()

# Save fig as png
plt.savefig('../output_data/Latitude_vs_Max_Temperature.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set x and y values
x_values = city_data['Latitude']
y_values = city_data['Humidity (%)']

# Create scatter plot.  Set edgecolor
plt.scatter(x_values,y_values, edgecolor = 'black')

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (01/24/2021)')

# Grid and display scatter plot
plt.grid(zorder=0)
plt.show()

# Save fig as png
plt.savefig('../output_data/Latitude_vs_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Set x and y values
x_values = city_data['Latitude']
y_values = city_data['Cloudiness (%)']

# Create scatter plot.  Set edgecolor
plt.scatter(x_values,y_values, edgecolor = 'black')

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (01/24/2021)')

# Grid and display scatter plot
plt.grid(zorder=0)
plt.show()

# Save fig as png
plt.savefig('../output_data/Latitude_vs_Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Set x and y values
x_values = city_data['Latitude']
y_values = city_data['Wind Speed (mph)']

# Create scatter plot.  Set edgecolor
plt.scatter(x_values,y_values, edgecolor = 'black')

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (01/24/2021)')

# Grid and display scatter plot
plt.grid(zorder=0)
plt.show()

# Save fig as png
plt.savefig('../output_data/Latitude_vs_Wind_Speed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create northern and southern hemisphere variables. 
# Northern Hemisphere (greater than or equal to 0 degrees latitude) 
# Southern Hemisphere (less than 0 degrees latitude)
north_hem = city_data.loc[(city_data['Latitude'] >= 0) & (city_data['Latitude'] <= 90)]
south_hem = city_data.loc[(city_data['Latitude'] >= -90) & (city_data['Latitude'] < 0 )]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = north_hem['Latitude']
y_values = north_hem['Max Temperature (F)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Create scatter plot with line equation.  Annotate line of equation
t = x_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(5,-50),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.grid(zorder = 0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Northern Hemisphere - Temperature (F) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.803386698400227

# %%
#Analysis: it appears to have a negative correlation, the farther you are from the equater tjer lower the max temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = south_hem['Latitude']
y_values = south_hem['Max Temperature (F)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = x_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.grid(zorder = 0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Southern Hemisphere - Temperature (F) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.3280365975324635

# %%
#Analysis: there is some mixed data but overall a postive correlation with max temp increasing as you move from the south pole.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = north_hem['Latitude']
y_values = north_hem['Humidity (%)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = y_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(40,12),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude')
plt.grid(zorder = 0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Northern Hemisphere - Humidity (%) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.045726183202882846

# %%
#analysis: there seems to be a postive correlation, the further you are from the equator the higher the humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = south_hem['Latitude']
y_values = south_hem['Humidity (%)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = y_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-24,12),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude')
plt.grid(zorder=0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Southern Hemisphere - Humidity (%) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.06956445589696067

# %%
#analysis: There seems to be a slightly positive correlation the closer to the equator the more humidity

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = north_hem['Latitude']
y_values = north_hem['Cloudiness (%)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = x_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(40,12),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude')
plt.grid(zorder=0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.04206500392730395

# %%
#analysis: the data is spread all over with a postive correlcation but too wide to make a call

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = south_hem['Latitude']
y_values = south_hem['Cloudiness (%)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = x_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude')
plt.grid(zorder=0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.040317160393092806

# %%
#analysis the data is spread all over with a postive correlcation but too wide to make a good call

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = north_hem['Latitude']
y_values = north_hem['Wind Speed (mph)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = y_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(5,35),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude')
plt.grid(zorder=0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.028260340239210216

# %%
#analysis there is a genral positve correlation but its just slight

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y axis.  
x_values = south_hem['Latitude']
y_values = south_hem['Wind Speed (mph)']

# Create slope equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot with line equation.  Annotate line of equation
t = y_values
plt.scatter(x_values,y_values, edgecolor = 'black', c=t)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-55,26),fontsize=15,color="red")

# Title, x label and y label
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude')
plt.grid(zorder=0)

# Print r value
print(f"The r-squared is: {rvalue**2}")

# Display scatter plot with equation and line
plt.show()

# Save fig as png
plt.savefig('../output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude.png')
plt.show()
# Out:
# The r-squared is: 0.0969587529709884

# %%
#analysis: there is a negative correlation with less wind as you go towards the equator.
